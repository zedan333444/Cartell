# %% [markdown]
# introduction
# The Anime Dataset is a collection of animes with alot of information that make you understand every thing about anime. these dataset contains 18494 row and 17 columns.These columns have all informatin about like(name,japanese name,type,rank,rating,etc). We use different packages like(pandas,numpy, matplotlib.pyplot,seaborn), Before the analysis of the dataset we make cleaning for the dataset (removing unuse and unimportant columns or row , handling missing values , handlig duplication (if there)

# %% [markdown]
# Analysis of the DataSet (questions that is analyized in the dataset):
# 1-information about the top 10 Animes
#
# 2-information about the Distribution of Rating and Release_year
#
# 3-Relationship between Release_year and Rating
#
# 4-Information about the Rating using "boxplot"
#
# 5-Information about the avrage of Ranig and Release_year
#
# 6- Information about types of Anime
#
# 7-Correlation matrix between Rating ,Release_year, Episodes
#
# 8-Relationship between every two columns (intiger or flotes)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("E:/STUDY/btn/Anime.csv")

# %%
data
# Out:
#         Rank                                               Name  \
# 0          1  Demon Slayer: Kimetsu no Yaiba - Entertainment...
# 1          2                     Fruits Basket the Final Season
# 2          3                                    Mo Dao Zu Shi 3
# 3          4                   Fullmetal Alchemist: Brotherhood
# 4          5                Attack on Titan 3rd Season: Part II
# ...      ...                                                ...
# 18490  18491  Qin Shi Mingyue: Canghai Hengliu Xiaomeng Spec...
# 18491  18492                      Yi Tang Juchang: Sanguo Yanyi
# 18492  18493          Fenghuang Ji Xiang Yu Qingming Shanghe Tu
# 18493  18494                      Chengshi Jiyi Wo Men de Jieri
# 18494  18495  Heisei Inu Monogatari Bow: Genshi Inu Monogata...
#
#                                          Japanese_name   Type  Episodes  \
# 0                        Kimetsu no Yaiba: Yuukaku-hen  TV          NaN
# ...

# %% [markdown]
# Data cleaning

# %%
#shows how many cells are empty in each column
data.isnull().sum()
# Out:
# Rank                   0
# Name                   0
# Japanese_name      10557
# Type                   0
# Episodes            8994
# Studio              6477
# Release_season     14379
# Tags                 400
# Rating              3131
# Release_year         383
# End_year           15641
# Description            4
# Content_Warning    16655
# Related_Mange      10868
# Related_anime       8432
# Voice_actors        3186
# staff               5490
# dtype: int64
